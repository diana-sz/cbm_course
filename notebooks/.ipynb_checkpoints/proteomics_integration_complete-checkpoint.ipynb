# %% [markdown]
# # Proteomics integration with an enzyme constrained model
# In this notebook we are going to integrate proteomics data from [Schmidt et al. 2016](https://doi.org/10.1038/nbt.3418) into an enzyme constrained model of E. coli (eciML1515).

# %%
import pandas as pd
import cobra
from cobra.flux_analysis import flux_variability_analysis

# model from https://github.com/ginkgobioworks/geckopy/tree/master/tests/data
model = cobra.io.read_sbml_model('../models/eciML1515.xml.gz')

model.solver.configuration.presolve = True

# %%
def limit_proteins(model, measurements, error = 0):
    """Apply proteomics measurements to `model`.

    Adapted from https://github.com/DD-DeCaF/simulations/blob/devel/src/simulations/modeling/driven.py

    Parameters
    ----------
    model: cobra.Model
        The enzyme-constrained model.
    measurements : pd.DataFrame
        Protein abundances in mmol / gDW.

    """
    for protein_id, measure in measurements.items():
        try:
            rxn = model.reactions.get_by_id(f"prot_{protein_id}_exchange")
        except KeyError:
            pass
        else:
            # update only upper_bound (as enzymes can be unsaturated):
            rxn.bounds = (0, measure + measure*error)

# %%
def top_shadow_prices(solution, met_ids, top=1):
    """
    Retrieves shadow prices for a list of metabolites from the solution and ranks
    them from most to least sensitive in the model.

    Parameters
    ----------
    solution: cobra.Solution
        The usual Solution object returned by model.optimize().
    biomass_reaction: str
        name of biomass reaction
    met_ids: iterable of strings
        Subset of metabolite IDs from the model.
    top: int
        The number of metabolites to be returned.

    Returns
    -------
    shadow_pr: pd.Series
        Top shadow prices, ranked.
    """
    shadow_pr = solution.shadow_prices
    shadow_pr = shadow_pr.loc[shadow_pr.index.isin(met_ids)]
    return shadow_pr.sort_values()[:top]



def protein_to_metabolite(protein_id, model):
    met_id = model.metabolites.query(lambda m: protein_id in m.id)
    return met_id[0].id if met_id else ""



def flexibilize_proteomics(model, biomass_reaction, minimal_growth, proteomics):
    """
    Replace proteomics measurements with a set that enables the model to grow. Proteins
    are removed from the set iteratively based on sensitivity analysis (shadow prices).
    
    Adapted from https://github.com/DD-DeCaF/simulations/blob/devel/src/simulations/modeling/driven.py

    Parameters
    ----------
    model: cobra.Model
        The enzyme-constrained model.
    minimal_growth_rate: float
        Minimal growth rate to enforce.
    proteomics: pandas.DataFrame
        List of measurements.

    Returns
    -------
    growth_rate: dict
        New growth rate (will change if the model couldn't grow at the inputted value).
    proteomics: list(dict)
        Filtered list of proteomics.

    """
    def protein_to_metabolite(protein_id, model):
        met_id = model.metabolites.query(lambda m: protein_id in m.id)
        return met_id[0].id if met_id else ""

    # reset growth rate in model:
    model.reactions.get_by_id(biomass_reaction).bounds = (0, 1000)

    # build a table with protein ids, met ids in model and values to constrain with:
    prot_df = pd.DataFrame(proteomics)
    prot_df.index = prot_df.index.astype("str")
    prot_df["met_id"] = [protein_to_metabolite(prot, model) for prot in prot_df.index]
    prot_df = prot_df[prot_df.met_id != ""]

    # constrain the model with all proteins and optimize:
    limit_proteins(model, proteomics)
    solution = model.optimize()
    new_growth_rate = solution.objective_value if solution.objective_value else 0

    # while the model cannot grow to the desired level, remove the protein with
    # the highest shadow price:
    prots_to_remove = []
    no_improvement = 0
    while new_growth_rate < minimal_growth and not prot_df.empty:
        # get most influential protein in model:
        top_protein = top_shadow_prices(solution, list(prot_df["met_id"]))
        top_protein = top_protein.index[0]
        top_protein = prot_df.index[prot_df["met_id"] == top_protein][0]

        # update data: append protein to list, remove from current dataframe and
        # increase the corresponding upper bound to +1000:
        prots_to_remove.append(top_protein)
        prot_df = prot_df.drop(labels=top_protein)
        rxn = model.reactions.get_by_id(f"prot_{top_protein}_exchange")
        current = rxn.upper_bound
        rxn.bounds = (0, 1000)# current*100)

        # re-compute solution:
        solution = model.optimize()

        if solution:
            if (solution.objective_value - new_growth_rate) < 1e-5:  # the algorithm is stuck
               no_improvement += 1

        if no_improvement > 30:
            break

        new_growth_rate = solution.objective_value if solution else 0
        print((top_protein, new_growth_rate))

    # update growth rate if optimization was not successful:
    if new_growth_rate < minimal_growth:
        print(
            f"Minimal growth was not reached! "
            f"Final growth of the model: {new_growth_rate}"
        )

    return new_growth_rate, prots_to_remove

# %% [markdown]
# # How are proteins represented in an ecModel?

# %% [markdown]
# Each reaction has the corresponding protein as a substrate

# %%
model.reactions.PYK2No1
# Out:
# <Reaction PYK2No1 at 0x7fc416daae10>

# %% [markdown]
# The protein has an exchange reaction - the upper bound on this reaction can be constrained by proteomics data

# %%
model.reactions.prot_P21599_exchange
# Out:
# <Reaction prot_P21599_exchange at 0x7fc41683bf90>

# %% [markdown]
# Let's check the growth rate of the model before integrating proteomics

# %%
model.optimize()
summary = model.summary()
summary
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ec_iML1515_core_75p37M = 0.8769973133963862</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e_REV</td>
#       <td>0.004565</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e_REV</td>
#       <td>0.004565</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e_REV</td>
#       <td>2.192E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e_REV</td>
#       <td>0.0006218</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e_REV</td>
#       <td>0.01409</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e_REV</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e_REV</td>
#       <td>0.1712</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e_REV</td>
#       <td>0.007608</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e_REV</td>
#       <td>0.000606</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mobd_e</td>
#       <td>EX_mobd_e_REV</td>
#       <td>6.139E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e_REV</td>
#       <td>9.471</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ni2_e</td>
#       <td>EX_ni2_e_REV</td>
#       <td>0.0002833</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e_REV</td>
#       <td>22.13</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e_REV</td>
#       <td>0.846</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e_REV</td>
#       <td>0.2208</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e_REV</td>
#       <td>0.0002991</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_O32583</td>
#       <td>prot_O32583_exchange</td>
#       <td>4.527E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00350</td>
#       <td>prot_P00350_exchange</td>
#       <td>2.96E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00547</td>
#       <td>prot_P00547_exchange</td>
#       <td>7.249E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00562</td>
#       <td>prot_P00562_exchange</td>
#       <td>7.532E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00861</td>
#       <td>prot_P00861_exchange</td>
#       <td>5.342E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00864</td>
#       <td>prot_P00864_exchange</td>
#       <td>1.335E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00895</td>
#       <td>prot_P00895_exchange</td>
#       <td>1.003E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00903</td>
#       <td>prot_P00903_exchange</td>
#       <td>2.432E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00904</td>
#       <td>prot_P00904_exchange</td>
#       <td>3.247E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00909</td>
#       <td>prot_P00909_exchange</td>
#       <td>1.766E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00934</td>
#       <td>prot_P00934_exchange</td>
#       <td>3.314E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00935</td>
#       <td>prot_P00935_exchange</td>
#       <td>3.099E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00963</td>
#       <td>prot_P00963_exchange</td>
#       <td>1.957E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P02919</td>
#       <td>prot_P02919_exchange</td>
#       <td>1.254E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04036</td>
#       <td>prot_P04036_exchange</td>
#       <td>4.756E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04079</td>
#       <td>prot_P04079_exchange</td>
#       <td>2.479E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04693</td>
#       <td>prot_P04693_exchange</td>
#       <td>1.222E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04805</td>
#       <td>prot_P04805_exchange</td>
#       <td>3.951E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04951</td>
#       <td>prot_P04951_exchange</td>
#       <td>4.329E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05020</td>
#       <td>prot_P05020_exchange</td>
#       <td>3.249E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05041</td>
#       <td>prot_P05041_exchange</td>
#       <td>2.432E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05194</td>
#       <td>prot_P05194_exchange</td>
#       <td>2.995E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05791</td>
#       <td>prot_P05791_exchange</td>
#       <td>2.162E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05793</td>
#       <td>prot_P05793_exchange</td>
#       <td>1.092E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06715</td>
#       <td>prot_P06715_exchange</td>
#       <td>1.643E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06959</td>
#       <td>prot_P06959_exchange</td>
#       <td>7.102E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06983</td>
#       <td>prot_P06983_exchange</td>
#       <td>1.738E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06988</td>
#       <td>prot_P06988_exchange</td>
#       <td>1.592E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06989</td>
#       <td>prot_P06989_exchange</td>
#       <td>4.662E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06999</td>
#       <td>prot_P06999_exchange</td>
#       <td>2.493E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07004</td>
#       <td>prot_P07004_exchange</td>
#       <td>6.062E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07014</td>
#       <td>prot_P07014_exchange</td>
#       <td>9.931E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07623</td>
#       <td>prot_P07623_exchange</td>
#       <td>1.021E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07862</td>
#       <td>prot_P07862_exchange</td>
#       <td>4.339E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08142</td>
#       <td>prot_P08142_exchange</td>
#       <td>6.997E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08178</td>
#       <td>prot_P08178_exchange</td>
#       <td>2.726E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08179</td>
#       <td>prot_P08179_exchange</td>
#       <td>2.714E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08200</td>
#       <td>prot_P08200_exchange</td>
#       <td>1.805E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08244</td>
#       <td>prot_P08244_exchange</td>
#       <td>1.919E-06</

# %% [markdown]
# In the summary you can see which proteins are being used by the model and their amounts.
# However, this model does not have the constraint on the total protein pool, so these predictions might not be realistic.

# %% [markdown]
# ## Proteomics integration
# ### Reading and processing the data
# We will use a dataset from Schmidt 2016. In this publication they measured proteome of E. coli in various conditions.

# %%
# proteomics data
df = pd.read_csv(
    "../data/ecoli_proteomics_schmidt2016_S5_ren.tsv", # BW25113 22 media
    sep="\t", skiprows=2  # skip titles and subtitles (XLXS)
)

# metadata
exp_details = pd.read_csv(
    "../data/ecoli_details_schmidt2016_S23.tsv", 
    sep="\t",
    skiprows=2  # skip titles and subtitles (XLXS)
)

# %%
df.head(3)
# Out:
#   Uniprot Accession                                        Description  Gene  \
# 0            P0A8T7  DNA-directed RNA polymerase subunit beta' OS=E...  rpoC
# 1            P0A8V2  DNA-directed RNA polymerase subunit beta OS=Es...  rpoB
# 2            P36683  Aconitate hydratase 2 OS=Escherichia coli (str...  acnB
#
#    Peptides used for quantitation  Confidence score  Molecular weight (Da)  \
# 0                              91           6045.53            155045.0080
# 1                              89           5061.29            150520.2758
# 2                              67           4505.67             93420.9457
#
#    Glucose_copies  LB_copies  Glycerol + AA_copies  Acetate_copies  ...  \
# 0            2779       7164                  4503            2180  ...
# 1            3957       8888                  5199            2661  ...
# 2            7596      16600                 17548           22844  ...
#
#    Stationary phase 1 day_cv  Stationary phase 3 days_cv  \
# 0                       6.76                       12.08
# 1                      14.42                       11.18
# 2                       3.93                       10.04
#
#    Osmotic-stress glucose_cv  42°C glucose_cv  pH6 glucose_cv  Xylose_cv  \
# 0                      20.91            13.86            6.14       6.27
# 1                      17.48            10.51            5.93       4.27
# 2                      16.60             9.57            4.47      21.78
#
#    Mannose_cv  Galactose _cv  Succinate_cv  Fructose_cv
# 0       16.15          22.87         16.45         9.29
# 1       13.51          19.75         13.60         7.77
# 2        3.16           2.07          4.21         3.25
#
# [3 rows x 72 columns]

# %%
exp_details.head(10)
# Out:
#   Growth condition   Strain  Growth rate (h-1)  Stdev  \
# 0               LB  BW25113               1.90  0.030
# 1               LB   MG1665               1.78  0.050
# 2               LB  NCM3722               2.30  0.050
# 3    Glycerol + AA  BW25113               1.27  0.010
# 4          Acetate  BW25113               0.30  0.040
# 5         Fumarate  BW25113               0.42  0.020
# 6       Galactose   BW25113               0.26  0.003
# 7          Glucose  BW25113               0.58  0.010
# 8          Glucose   MG1665               0.67  0.070
# 9          Glucose  NCM3722               1.03  0.060
#
#    Single cell volume [fl]1 Doubling time (h-1) Time exp before harvest (h)  \
# 0                      4.29                 0.4                           5
# 1                      4.23                 0.4                         5.4
# 2                      4.36                 0.3                         3.2
# 3                      3.83                 0.5                         7.5
# 4                      2.30                 2.3                        29.3
# 5                      2.54                 1.7                        25.4
# 6                      2.21                 2.7                        52.1
# 7                      2.84                 1.2                        22.7
# 8                      3.00                   1                          22
# 9                      3.54                 0.7                        19.9
#
#   # of doublings at exponential growth before harvesting  \
# 0                                               13.7
# 1                                               13.9
# 2                                               10.6
# 3                                               13.8
# 4                                               12.7
# 5                                               15.2
# 6                                               19.2
# 7                                               19.1
# 8                                               21.4
# 9                                               29.6
#
#    OD @ harvesting. replicates  Unnamed: 9  Unnamed: 10  \
# 0                         1.80        1.37         1.34
# 1                         0.53        1.09         1.32
# 2                         0.91        0.96         1.00
# 3                         0.50        0.51         0.50
# 4                         0.53        0.22         0.48
# 5                         0.22        0.20         0.14
# 6                         2.02        2.03         2.02
# 7                         0.40        0.43         0.39
# 8                         0.62        0.38         0.63
# 9                         1.06        1.03         1.41
#
#    Number of Proteins Identified (FDR 1%)2
# 0                                   1752.0
# 1                                   1733.0
# 2                                   1703.0
# 3                                   1675.0
# 4                                   1683.0
# 5                                   1696.0
# 6                                   1650.0
# 7                                   1702.0
# 8                                   1706.0
# 9                                   1761.0

# %%
# select column with protein copy numbers, coefficient of variation and UniProt accession number
df = df.loc[:, 
    df.columns.str.contains("_copies|_cv", 
                            regex=True) |  # only interested in copies/cell and uncertainty
    df.columns.isin(["Uniprot Accession"])  # and relevant info about proteins
]
df=df.drop(2047, axis=0)

# %%
# select one condition
condition = "Glucose"
df_ac = df.loc[:, ["Uniprot Accession", f"{condition}_copies", f"{condition}_cv"]]
# rename resulting columns
df_ac.columns = ["uniprot", "copies_per_cell", "CV"]

# %%
df_ac.describe()
# Out:
#        copies_per_cell           CV
# count      2057.000000  2057.000000
# mean       2451.522606    23.619208
# std        9434.381168    25.353809
# min           0.000000     0.090000
# 25%          39.000000     8.940000
# 50%         229.000000    15.370000
# 75%        1255.000000    27.730000
# max      252452.000000   172.560000

# %%
# apply uncertainty (extend upper bound by 3x coefficient of variation)
df_ac["copies_upper"] = df_ac["copies_per_cell"] + 3*df_ac["CV"]/100 * df_ac["copies_per_cell"]

# %%
# convert units from copies to mmoles
df_ac["mmol_per_cell"] = df_ac["copies_upper"] * 1e3/6.022e23

# %%
# extract cell volume
cell_volume = exp_details.loc[
    (exp_details["Growth condition"] == condition),# & 
    #(exp_details["Strain"] == "BW25113"),
    "Single cell volume [fl]1"
].mean()

# %%
cell_volume
# Out:
# np.float64(3.1266666666666665)

# %%
# calculate concentration (mmol per g cell dry weight)
cell_density = 0.34  # https://bionumbers.hms.harvard.edu/bionumber.aspx?id=109049
df_ac["conc"] = df_ac["mmol_per_cell"]/cell_volume * 1e12 / (cell_density  * cell_density)

# %%
# extract experimental growth rate
growth_experimental = exp_details.loc[
    (exp_details["Growth condition"] == condition),# & 
    #(exp_details["Strain"] == "BW25113"),
    "Growth rate (h-1)"
].mean()
growth_experimental
# Out:
# np.float64(0.7600000000000001)

# %%
proteomics = df_ac["conc"]
proteomics.index = df_ac["uniprot"]

# %%
# save the non enzyme-constrained model
plain_model = model.copy()

# %% [markdown]
# ### Integrate proteomics

# %%
limit_proteins(model, proteomics)
model.optimize()
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ec_iML1515_core_75p37M = 0.005551631090862522</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e_REV</td>
#       <td>2.89E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e_REV</td>
#       <td>2.89E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e_REV</td>
#       <td>1.388E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e_REV</td>
#       <td>3.936E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e_REV</td>
#       <td>8.916E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e_REV</td>
#       <td>2.12</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e_REV</td>
#       <td>0.001084</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e_REV</td>
#       <td>4.816E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e_REV</td>
#       <td>3.836E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e_REV</td>
#       <td>0.05996</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ni2_e</td>
#       <td>EX_ni2_e_REV</td>
#       <td>1.793E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e_REV</td>
#       <td>2.73</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e_REV</td>
#       <td>0.005355</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e_REV</td>
#       <td>0.001398</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e_REV</td>
#       <td>1.893E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00547</td>
#       <td>prot_P00547_exchange</td>
#       <td>1.774E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00561</td>
#       <td>prot_P00561_exchange</td>
#       <td>1.543E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00934</td>
#       <td>prot_P00934_exchange</td>
#       <td>8.115E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00963</td>
#       <td>prot_P00963_exchange</td>
#       <td>1.239E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04079</td>
#       <td>prot_P04079_exchange</td>
#       <td>1.569E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05020</td>
#       <td>prot_P05020_exchange</td>
#       <td>2.057E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06959</td>
#       <td>prot_P06959_exchange</td>
#       <td>1.584E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06988</td>
#       <td>prot_P06988_exchange</td>
#       <td>1.008E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06999</td>
#       <td>prot_P06999_exchange</td>
#       <td>6.565E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08178</td>
#       <td>prot_P08178_exchange</td>
#       <td>1.726E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08839</td>
#       <td>prot_P08839_exchange</td>
#       <td>3.476E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P09029</td>
#       <td>prot_P09029_exchange</td>
#       <td>1.17E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6A3</td>
#       <td>prot_P0A6A3_exchange</td>
#       <td>2.412E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6A8</td>
#       <td>prot_P0A6A8_exchange</td>
#       <td>1.04E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6B7</td>
#       <td>prot_P0A6B7_exchange</td>
#       <td>1.012E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6C5</td>
#       <td>prot_P0A6C5_exchange</td>
#       <td>5.848E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6E4</td>
#       <td>prot_P0A6E4_exchange</td>
#       <td>6.638E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6E6</td>
#       <td>prot_P0A6E6_exchange</td>
#       <td>2.487E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6P9</td>
#       <td>prot_P0A6P9_exchange</td>
#       <td>2.879E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6T1</td>
#       <td>prot_P0A6T1_exchange</td>
#       <td>2.031E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6T5</td>
#       <td>prot_P0A6T5_exchange</td>
#       <td>2.948E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A717</td>
#       <td>prot_P0A717_exchange</td>
#       <td>2.179E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A799</td>
#       <td>prot_P0A799_exchange</td>
#       <td>4.36E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A7D4</td>
#       <td>prot_P0A7D4_exchange</td>
#       <td>1.57E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A7E3</td>
#       <td>prot_P0A7E3_exchange</td>
#       <td>1.594E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A825</td>
#       <td>prot_P0A825_exchange</td>
#       <td>1.542E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A858</td>
#       <td>prot_P0A858_exchange</td>
#       <td>7.691E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A953</td>
#       <td>prot_P0A953_exchange</td>
#       <td>2.968E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A991</td>
#       <td>prot_P0A991_exchange</td>
#       <td>2.38E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A9B2</td>
#       <td>prot_P0A9B2_exchange</td>
#       <td>1.64E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A9C5</td>
#       <td>prot_P0A9C5_exchange</td>
#       <td>8.052E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A9N4</td>
#       <td>prot_P0A9N4_exchange</td>
#       <td>1.085E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A9P0</td>
#       <td>prot_P0A9P0_exchange</td>
#       <td>1.584E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AA04</td>
#       <td>prot_P0AA04_exchange</td>
#       <td>3.476E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AAJ3</td>
#       <td>prot_P0AAJ3_exchange</td>
#       <td>4.441E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AB71</td>
#       <td>prot_P0AB71_exchange</td>
#       <td>0.0001126</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AB77</td>
#       <td>prot_P0AB77_exchange</td>
#       <td>5.782E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AB98</td>
#       <td>prot_P0AB98_exchange</td>
#       <td>2.487E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0ABA0</td>
#       <td>prot_P0ABA0_exchange</td>
#       <td>2.487E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0ABA4</td>
#       <td>prot_P0ABA4_exchange</td

# %% [markdown]
# We observe that the growth rate is now very low. This is because we have just included more than 2000 new constraints and their experimental errors add up.

# %% [markdown]
# ### We need to relax some constraints
# To do that, we relax proteins that influence the growth rate the most (have the highest shadow prices) one by one until the target growth rate is eached.

# %%
biomass_reaction = "BIOMASS_Ec_iML1515_core_75p37M"
new_growth_rate, prots_removed = flexibilize_proteomics(model, biomass_reaction, growth_experimental*0.9, proteomics)
# Out:
# ('P0A7E3', 0.005808325146965149)
# ('P15254', 0.011907048951857917)
# ('P60782', 0.011907048951857912)
# ('P31119', 0.01509917737298079)
# ('P0A6X1', 0.0204109472282912)
# ('P21151', 0.02555142237937021)
# ('P0A6C5', 0.03269752605581791)
# ('P0AD65', 0.039394725584286146)
# ('P27300', 0.05813822043507452)
# ('P0AD68', 0.06087682328900411)
# ('P17854', 0.07205325219895482)
# ('Q47146', 0.07576189028021905)
# ('P0AC16', 0.09157133851432961)
# ('P0ABG1', 0.09188613924492049)
# ('P0A6W3', 0.10725365219107008)
# ('P14900', 0.11561096729013522)
# ('P09029', 0.15857449347848757)
# ('P0A6I9', 0.2002092542377616)
# ('P00547', 0.2005618449103512)
# ('P11446', 0.23134030843294037)
# ('P56580', 0.23134030846493406)
# ('P76014', 0.24022901716875014)
# ('P37349', 0.2629676912903388)
# ('P76015', 0.26302788000838995)
# ('P17952', 0.2764074025481077)
# ('P76085', 0.2764074025480886)
# ('P76078', 0.2764074025480886)
# ('P76081', 0.27640740254808244)
# ('P0AC44', 0.2767481449750867)
# ('P07001', 0.27786631661302036)
# ('P0A953', 0.2785151193424046)
# ('P68699', 0.2798861314817415)
# ('P0A725', 0.2815773436822189)
# ('P0AB98', 0.28420873159724724)
# ('P0ABA6', 0.28507863462775945)
# ('P77718', 0.28973784440409767)
# ('P33607', 0.2917178160369959)
# ('P0AFE8', 0.29430648646039337)
# ('P0AFF0', 0.30189198164430414)
# ('P0ABA4', 0.30827435385783486)
# ('P0ABA0', 0.32012632327095997)
# ('P0A6E6', 0.3220628135599368)
# ('P0AFD4', 0.3264764537294187)
# ('P0ABB0', 0.33918093154479667)
# ('P22939', 0.3400780340813987)
# ('P0AC75', 0.3415667447179452)
# ('P0AFE4', 0.34333027064649746)
# ('P0AFC7', 0.34393088918213954)
# ('P0AFD6', 0.35304630655707697)
# ('P0ABB4', 0.3652487873380035)
# ('P09053', 0.36747630556399236)
# ('P31979', 0.4019147928938338)
# ('P15639', 0.40338189893100906)
# ('P0AFC3', 0.41272780090645256)
# ('P0AFD1', 0.41477476677844344)
# ('P08178', 0.4221783102935144)
# ('P0ABJ3', 0.4291743755605595)
# ('P0A6E4', 0.42917759363259717)
# ('P0ABJ6', 0.48826495576381207)
# ('P22188', 0.4922218592493287)
# ('P0ABI8', 0.5183482068724152)
# ('P36683', 0.5541499298829677)
# ('P00934', 0.6089757722568527)
# ('P33602', 0.6130949397006694)
# ('P0AGG0', 0.6187634414911815)
# ('P00861', 0.6188616888948816)
# ('P0A9P4', 0.6193196238321594)
# ('P0AED7', 0.6209139022065555)
# ('P69054', 0.6486144081605375)
# ('P06983', 0.651355416568)
# ('P33599', 0.6546830987462858)
# ('P22634', 0.6772940228211798)
# ('P0AC41', 0.6799092288195842)
# ('P05020', 0.705770358587374)

# %% [markdown]
# We see that only a small fraction of proteins needed to be relaxed

# %%
percentage_removed = round(len(prots_removed)/proteomics.shape[0]*100, 1)
print(f"Proteins in dataset: {proteomics.shape[0]}\nProteins removed: {len(prots_removed)} ({percentage_removed}%)")
# Out:
# Proteins in dataset: 2057
# Proteins removed: 74 (3.6%)

# %%
fluxes = model.optimize()
fluxes.fluxes.to_csv(f"../results/ecModel_{condition}_flux_results.csv")
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ec_iML1515_core_75p37M = 0.705770358587374</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e_REV</td>
#       <td>0.003674</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e_REV</td>
#       <td>0.003674</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e_REV</td>
#       <td>1.764E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e_REV</td>
#       <td>0.0005004</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e_REV</td>
#       <td>0.01134</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e_REV</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e_REV</td>
#       <td>0.1378</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e_REV</td>
#       <td>0.006123</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e_REV</td>
#       <td>0.0004877</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mobd_e</td>
#       <td>EX_mobd_e_REV</td>
#       <td>4.94E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e_REV</td>
#       <td>7.622</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ni2_e</td>
#       <td>EX_ni2_e_REV</td>
#       <td>0.000228</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e_REV</td>
#       <td>29.52</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e_REV</td>
#       <td>0.6808</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e_REV</td>
#       <td>0.1777</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e_REV</td>
#       <td>0.0002407</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_O32583</td>
#       <td>prot_O32583_exchange</td>
#       <td>3.643E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00350</td>
#       <td>prot_P00350_exchange</td>
#       <td>5.236E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00547</td>
#       <td>prot_P00547_exchange</td>
#       <td>2.364E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00561</td>
#       <td>prot_P00561_exchange</td>
#       <td>2.049E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00861</td>
#       <td>prot_P00861_exchange</td>
#       <td>4.299E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00864</td>
#       <td>prot_P00864_exchange</td>
#       <td>1.678E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00903</td>
#       <td>prot_P00903_exchange</td>
#       <td>1.958E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00904</td>
#       <td>prot_P00904_exchange</td>
#       <td>2.613E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00909</td>
#       <td>prot_P00909_exchange</td>
#       <td>1.421E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00934</td>
#       <td>prot_P00934_exchange</td>
#       <td>0.0001081</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00935</td>
#       <td>prot_P00935_exchange</td>
#       <td>2.494E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00963</td>
#       <td>prot_P00963_exchange</td>
#       <td>1.575E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P02918</td>
#       <td>prot_P02918_exchange</td>
#       <td>2.57E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P02919</td>
#       <td>prot_P02919_exchange</td>
#       <td>7.74E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04036</td>
#       <td>prot_P04036_exchange</td>
#       <td>3.828E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04079</td>
#       <td>prot_P04079_exchange</td>
#       <td>1.891E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04693</td>
#       <td>prot_P04693_exchange</td>
#       <td>1.469E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04805</td>
#       <td>prot_P04805_exchange</td>
#       <td>3.179E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04951</td>
#       <td>prot_P04951_exchange</td>
#       <td>3.483E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05020</td>
#       <td>prot_P05020_exchange</td>
#       <td>2.615E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05041</td>
#       <td>prot_P05041_exchange</td>
#       <td>1.958E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05194</td>
#       <td>prot_P05194_exchange</td>
#       <td>2.41E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05791</td>
#       <td>prot_P05791_exchange</td>
#       <td>1.74E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05793</td>
#       <td>prot_P05793_exchange</td>
#       <td>8.789E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06959</td>
#       <td>prot_P06959_exchange</td>
#       <td>4.453E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06983</td>
#       <td>prot_P06983_exchange</td>
#       <td>1.399E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06988</td>
#       <td>prot_P06988_exchange</td>
#       <td>1.281E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06989</td>
#       <td>prot_P06989_exchange</td>
#       <td>3.752E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06999</td>
#       <td>prot_P06999_exchange</td>
#       <td>9.267E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07004</td>
#       <td>prot_P07004_exchange</td>
#       <td>4.879E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07014</td>
#       <td>prot_P07014_exchange</td>
#       <td>1.524E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07623</td>
#       <td>prot_P07623_exchange</td>
#       <td>8.217E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08142</td>
#       <td>prot_P08142_exchange</td>
#       <td>5.631E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08178</td>
#       <td>prot_P08178_exchange</td>
#       <td>2.194E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08200</td>
#       <td>prot_P08200_exchange</td>
#       <td>2.591E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08244</td>
#       <td>prot_P08244_exchange</td>
#       <td>1.544E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08373</td>
#       <td>prot_P08373_exchange</td>
#       <td>2.715E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08660</td>
#       <td>prot_P08660_exchange</td>
#       <td>9.444E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08839</td>
#       <td>prot_P08839_exchange</td>
#       <td>1.698E-05</td>

# %% [markdown]
# ### Next steps
# As a next step, we could for example
# * visualize the fluxes in Escher or other software
# * perform flux variability analysis or sampling to characterize the solution space
# * compare it to unconstrained model - are the flux distributions different? Are different products secreted?
# * compare the different conditions (e.g. ask how does the metabolism rewire in rich vs poor medium, high temperature and other stressors...)
