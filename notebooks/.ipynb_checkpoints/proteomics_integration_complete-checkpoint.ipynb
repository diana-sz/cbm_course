# %% [markdown]
# # Proteomics integration with an enzyme constrained model
# In this notebook we are going to integrate proteomics data from [Schmidt et al. 2016](https://doi.org/10.1038/nbt.3418) into an enzyme constrained model of E. coli (eciML1515).

# %%
import re
import cobra
import escher
import pandas as pd
from cobra.flux_analysis import flux_variability_analysis

# model from https://github.com/ginkgobioworks/geckopy/tree/master/tests/data
model = cobra.io.read_sbml_model('../models/eciML1515.xml.gz')

model.solver.configuration.presolve = True

# %%
def limit_proteins(model, measurements, error = 0):
    """Apply proteomics measurements to `model`.

    Adapted from https://github.com/DD-DeCaF/simulations/blob/devel/src/simulations/modeling/driven.py

    Parameters
    ----------
    model: cobra.Model
        The enzyme-constrained model.
    measurements : pd.DataFrame
        Protein abundances in mmol / gDW.

    """
    n_constrained_proteins = 0
    for protein_id, amount in measurements.items():
        try:
            rxn = model.reactions.get_by_id(f"prot_{protein_id}_exchange")
        except KeyError:
            pass
        else:
            # update only upper_bound (as enzymes can be unsaturated):
            rxn.bounds = (0, amount + amount*error)
            n_constrained_proteins += 1
    print(f"{n_constrained_proteins} proteins constrained")

# %%
def top_shadow_prices(solution, met_ids, top=1):
    """
    Retrieves shadow prices for a list of metabolites from the solution and ranks
    them from most to least sensitive in the model.

    Parameters
    ----------
    solution: cobra.Solution
        The usual Solution object returned by model.optimize().
    biomass_reaction: str
        name of biomass reaction
    met_ids: iterable of strings
        Subset of metabolite IDs from the model.
    top: int
        The number of metabolites to be returned.

    Returns
    -------
    shadow_pr: pd.Series
        Top shadow prices, ranked.
    """
    shadow_pr = solution.shadow_prices
    shadow_pr = shadow_pr.loc[shadow_pr.index.isin(met_ids)]
    return shadow_pr.sort_values()[:top]



def protein_to_metabolite(protein_id, model):
    met_id = model.metabolites.query(lambda m: protein_id in m.id)
    return met_id[0].id if met_id else ""



def flexibilize_proteomics(model, biomass_reaction, minimal_growth, proteomics):
    """
    Replace proteomics measurements with a set that enables the model to grow. Proteins
    are removed from the set iteratively based on sensitivity analysis (shadow prices).
    
    Adapted from https://github.com/DD-DeCaF/simulations/blob/devel/src/simulations/modeling/driven.py

    Parameters
    ----------
    model: cobra.Model
        The enzyme-constrained model.
    biomass_reaction: string
        ID of the biomass reaction
    minimal_growth_rate: float
        Minimal growth rate to enforce.
    proteomics: pandas.DataFrame
        Proteomics measurements.

    Returns
    -------
    new_growth_rate: float
        New growth rate (will change if the model couldn't grow at the inputed value).
    prots_to_remove: list(dict)
        List of proteins for which proteomic constraints have been relaxed

    """
    def protein_to_metabolite(protein_id, model):
        met_id = model.metabolites.query(lambda m: protein_id in m.id)
        return met_id[0].id if met_id else ""

    # reset growth rate in model:
    model.reactions.get_by_id(biomass_reaction).bounds = (0, 1000)

    # build a table with protein ids, met ids in model and values to constrain with:
    prot_df = pd.DataFrame(proteomics)
    prot_df.index = prot_df.index.astype("str")
    prot_df["met_id"] = [protein_to_metabolite(prot, model) for prot in prot_df.index]
    prot_df = prot_df[prot_df.met_id != ""]

    # constrain the model with all proteins and optimize:
    limit_proteins(model, proteomics)
    solution = model.optimize()
    new_growth_rate = solution.objective_value if solution.objective_value else 0

    # while the model cannot grow to the desired level, remove the protein with
    # the highest shadow price:
    prots_to_remove = []
    no_improvement = 0
    while new_growth_rate < minimal_growth and not prot_df.empty:
        # get most influential protein in model:
        top_protein = top_shadow_prices(solution, list(prot_df["met_id"]))
        top_protein = top_protein.index[0]
        top_protein = prot_df.index[prot_df["met_id"] == top_protein][0]

        # update data: append protein to list, remove from current dataframe and
        # increase the corresponding upper bound to +1000:
        prots_to_remove.append(top_protein)
        prot_df = prot_df.drop(labels=top_protein)
        rxn = model.reactions.get_by_id(f"prot_{top_protein}_exchange")
        rxn.bounds = (0, max(proteomics)*10)  # value of the most abundant protein

        # re-compute solution:
        solution = model.optimize()

        if solution:
            if (solution.objective_value - new_growth_rate) < 1e-5:  # the algorithm is stuck
               no_improvement += 1

        if no_improvement > 30:
            break

        new_growth_rate = solution.objective_value if solution else 0
        print((top_protein, new_growth_rate))

    # update growth rate if optimization was not successful:
    if new_growth_rate < minimal_growth:
        print(
            f"Minimal growth was not reached! "
            f"Final growth of the model: {new_growth_rate}"
        )

    return new_growth_rate, prots_to_remove

# %% [markdown]
# ## How are proteins represented in an ecModel?

# %% [markdown]
# Each reaction has the corresponding protein as a substrate

# %%
model.reactions.PYK2No1.reaction
# Out:
# 'h_c + pep_c + 8.6697e-08 prot_P21599 + udp_c --> pyr_c + utp_c'

# %% [markdown]
# The protein has an exchange reaction - the upper bound on this reaction can be constrained by proteomics data

# %%
model.reactions.prot_P21599_exchange.reaction
# Out:
# ' --> prot_P21599'

# %%
model.reactions.F1PPNo1.reaction  # No1, No2, No3... - isoenzymes
# Out:
# 'pmet_F1PP + 1.445e-05 prot_P75792 --> fru_c + pi_c'

# %%
# in case of isoenzymes - a pseudometabolite is introduced
# done for convenience so that you can easily extract the total flux of this reaction or set a constraint
model.reactions.arm_F1PP.reaction
# Out:
# 'f1p_c + h2o_c --> pmet_F1PP'

# %%
model.reactions.ATPS4rppNo1.reaction  # reaction with subunits
# Out:
# 'pmet_ATPS4rpp + 1.3889e-05 prot_P0A6E6 + 1.3889e-05 prot_P0AB98 + 1.3889e-05 prot_P0ABA0 + 1.3889e-05 prot_P0ABA4 + 1.3889e-05 prot_P0ABA6 + 1.3889e-05 prot_P0ABB0 + 1.3889e-05 prot_P0ABB4 + 1.3889e-05 prot_P0ABC0 + 1.3889e-05 prot_P68699 --> atp_c + h2o_c + 3.0 h_c'

# %% [markdown]
# Let's check the growth rate of the model before integrating proteomics

# %% [markdown]
# In the summary you can see which proteins are being used by the model and their amounts.
# However, this model does not have the constraint on the total protein pool, so these predictions might not be realistic.

# %% [markdown]
# ## Read proteomics data
# We will use a dataset from Schmidt 2016. In this publication they measured proteome of E. coli in various conditions.

# %%
# proteomics data
df = pd.read_csv(
    "../data/ecoli_proteomics_schmidt2016_S5_ren.tsv", # BW25113 22 media
    sep="\t", skiprows=2  # skip titles and subtitles (XLXS)
)

# metadata
exp_details = pd.read_csv(
    "../data/ecoli_details_schmidt2016_S23.tsv", 
    sep="\t",
    skiprows=2  # skip titles and subtitles (XLXS)
)

# %%
df.head(2)
# Out:
#   Uniprot Accession                                        Description  Gene  \
# 0            P0A8T7  DNA-directed RNA polymerase subunit beta' OS=E...  rpoC
# 1            P0A8V2  DNA-directed RNA polymerase subunit beta OS=Es...  rpoB
#
#    Peptides used for quantitation  Confidence score  Molecular weight (Da)  \
# 0                              91           6045.53            155045.0080
# 1                              89           5061.29            150520.2758
#
#    Glucose_copies  LB_copies  Glycerol + AA_copies  Acetate_copies  ...  \
# 0            2779       7164                  4503            2180  ...
# 1            3957       8888                  5199            2661  ...
#
#    Stationary phase 1 day_cv  Stationary phase 3 days_cv  \
# 0                       6.76                       12.08
# 1                      14.42                       11.18
#
#    Osmotic-stress glucose_cv  42°C glucose_cv  pH6 glucose_cv  Xylose_cv  \
# 0                      20.91            13.86            6.14       6.27
# 1                      17.48            10.51            5.93       4.27
#
#    Mannose_cv  Galactose _cv  Succinate_cv  Fructose_cv
# 0       16.15          22.87         16.45         9.29
# 1       13.51          19.75         13.60         7.77
#
# [2 rows x 72 columns]

# %%
exp_details.head(6)
# Out:
#   Growth condition   Strain  Growth rate (h-1)  Stdev  \
# 0               LB  BW25113               1.90   0.03
# 1               LB   MG1665               1.78   0.05
# 2               LB  NCM3722               2.30   0.05
# 3    Glycerol + AA  BW25113               1.27   0.01
# 4          Acetate  BW25113               0.30   0.04
# 5         Fumarate  BW25113               0.42   0.02
#
#    Single cell volume [fl]1 Doubling time (h-1) Time exp before harvest (h)  \
# 0                      4.29                 0.4                           5
# 1                      4.23                 0.4                         5.4
# 2                      4.36                 0.3                         3.2
# 3                      3.83                 0.5                         7.5
# 4                      2.30                 2.3                        29.3
# 5                      2.54                 1.7                        25.4
#
#   # of doublings at exponential growth before harvesting  \
# 0                                               13.7
# 1                                               13.9
# 2                                               10.6
# 3                                               13.8
# 4                                               12.7
# 5                                               15.2
#
#    OD @ harvesting. replicates  Unnamed: 9  Unnamed: 10  \
# 0                         1.80        1.37         1.34
# 1                         0.53        1.09         1.32
# 2                         0.91        0.96         1.00
# 3                         0.50        0.51         0.50
# 4                         0.53        0.22         0.48
# 5                         0.22        0.20         0.14
#
#    Number of Proteins Identified (FDR 1%)2
# 0                                   1752.0
# 1                                   1733.0
# 2                                   1703.0
# 3                                   1675.0
# 4                                   1683.0
# 5                                   1696.0

# %%
# select column with protein copy numbers, coefficient of variation and UniProt accession number
df = df.loc[:, 
    df.columns.str.contains("_copies|_cv", regex=True) |  # only interested in copies/cell and uncertainty
    df.columns.isin(["Uniprot Accession"])  # and relevant info about proteins
]
df=df.drop(2047, axis=0)

# %% [markdown]
# ### select one condition

# %%
condition = "Glucose"
df_ac = df.loc[:, ["Uniprot Accession", f"{condition}_copies", f"{condition}_cv"]]
# rename resulting columns
df_ac.columns = ["uniprot", "copies_per_cell", "CV"]

# %% [markdown]
# ## Simulations with an unconstrained model

# %%
model.medium
# Out:
# {'EX_pi_e_REV': 1000.0,
#  'EX_mn2_e_REV': 1000.0,
#  'EX_fe2_e_REV': 1000.0,
#  'EX_glc__D_e_REV': 10.0,
#  'EX_zn2_e_REV': 1000.0,
#  'EX_mg2_e_REV': 1000.0,
#  'EX_ca2_e_REV': 1000.0,
#  'EX_ni2_e_REV': 1000.0,
#  'EX_cu2_e_REV': 1000.0,
#  'EX_cobalt2_e_REV': 1000.0,
#  'EX_nh4_e_REV': 1000.0,
#  'EX_mobd_e_REV': 1000.0,
#  'EX_so4_e_REV': 1000.0,
#  'EX_k_e_REV': 1000.0,
#  'EX_o2_e_REV': 1000.0,
#  'EX_cl_e_REV': 1000.0}

# %%
# save the non enzyme-constrained model
plain_model = model.copy()

# %%
fluxes_unconstrained = cobra.flux_analysis.pfba(plain_model)
plain_model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ec_iML1515_core_75p37M = 0.8769973133963807</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e_REV</td>
#       <td>0.004565</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e_REV</td>
#       <td>0.004565</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e_REV</td>
#       <td>2.192E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e_REV</td>
#       <td>0.0006218</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e_REV</td>
#       <td>0.01409</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e_REV</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e_REV</td>
#       <td>0.1712</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e_REV</td>
#       <td>0.007608</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e_REV</td>
#       <td>0.000606</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mobd_e</td>
#       <td>EX_mobd_e_REV</td>
#       <td>6.139E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e_REV</td>
#       <td>9.471</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ni2_e</td>
#       <td>EX_ni2_e_REV</td>
#       <td>0.0002833</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e_REV</td>
#       <td>22.13</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e_REV</td>
#       <td>0.846</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e_REV</td>
#       <td>0.2208</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e_REV</td>
#       <td>0.0002991</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_O32583</td>
#       <td>prot_O32583_exchange</td>
#       <td>4.527E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00350</td>
#       <td>prot_P00350_exchange</td>
#       <td>2.96E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00547</td>
#       <td>prot_P00547_exchange</td>
#       <td>7.249E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00562</td>
#       <td>prot_P00562_exchange</td>
#       <td>7.532E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00861</td>
#       <td>prot_P00861_exchange</td>
#       <td>5.342E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00864</td>
#       <td>prot_P00864_exchange</td>
#       <td>1.335E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00895</td>
#       <td>prot_P00895_exchange</td>
#       <td>1.003E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00903</td>
#       <td>prot_P00903_exchange</td>
#       <td>2.432E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00904</td>
#       <td>prot_P00904_exchange</td>
#       <td>3.247E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00909</td>
#       <td>prot_P00909_exchange</td>
#       <td>1.766E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00934</td>
#       <td>prot_P00934_exchange</td>
#       <td>3.314E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00935</td>
#       <td>prot_P00935_exchange</td>
#       <td>3.099E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00963</td>
#       <td>prot_P00963_exchange</td>
#       <td>1.957E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P02919</td>
#       <td>prot_P02919_exchange</td>
#       <td>1.254E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04036</td>
#       <td>prot_P04036_exchange</td>
#       <td>4.756E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04079</td>
#       <td>prot_P04079_exchange</td>
#       <td>2.479E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04693</td>
#       <td>prot_P04693_exchange</td>
#       <td>1.222E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04805</td>
#       <td>prot_P04805_exchange</td>
#       <td>3.951E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04951</td>
#       <td>prot_P04951_exchange</td>
#       <td>4.329E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05020</td>
#       <td>prot_P05020_exchange</td>
#       <td>3.249E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05041</td>
#       <td>prot_P05041_exchange</td>
#       <td>2.432E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05194</td>
#       <td>prot_P05194_exchange</td>
#       <td>2.995E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05791</td>
#       <td>prot_P05791_exchange</td>
#       <td>2.162E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05793</td>
#       <td>prot_P05793_exchange</td>
#       <td>1.092E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06715</td>
#       <td>prot_P06715_exchange</td>
#       <td>1.643E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06959</td>
#       <td>prot_P06959_exchange</td>
#       <td>7.102E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06983</td>
#       <td>prot_P06983_exchange</td>
#       <td>1.738E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06988</td>
#       <td>prot_P06988_exchange</td>
#       <td>1.592E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06989</td>
#       <td>prot_P06989_exchange</td>
#       <td>4.662E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06999</td>
#       <td>prot_P06999_exchange</td>
#       <td>2.493E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07004</td>
#       <td>prot_P07004_exchange</td>
#       <td>6.062E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07014</td>
#       <td>prot_P07014_exchange</td>
#       <td>9.931E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07623</td>
#       <td>prot_P07623_exchange</td>
#       <td>1.021E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07862</td>
#       <td>prot_P07862_exchange</td>
#       <td>4.339E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08142</td>
#       <td>prot_P08142_exchange</td>
#       <td>6.997E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08178</td>
#       <td>prot_P08178_exchange</td>
#       <td>2.726E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08179</td>
#       <td>prot_P08179_exchange</td>
#       <td>2.714E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08200</td>
#       <td>prot_P08200_exchange</td>
#       <td>1.805E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08244</td>
#       <td>prot_P08244_exchange</td>
#       <td>1.919E-06</

# %%
# apply uncertainty (extend upper bound by 3x coefficient of variation)
df_ac["copies_upper"] = df_ac["copies_per_cell"] + 3*df_ac["CV"]/100 * df_ac["copies_per_cell"]

# %%
# convert units from copies to mmoles
df_ac["mmol_per_cell"] = df_ac["copies_upper"] * 1e3/6.022e23

# %%
# extract cell volume
cell_volume = exp_details.loc[
    (exp_details["Growth condition"] == condition) & 
    (exp_details["Strain"] == "BW25113"),
    "Single cell volume [fl]1"
].mean()
cell_density = 0.34  # g / mL  # https://bionumbers.hms.harvard.edu/bionumber.aspx?id=109049

# %%
cell_mass = cell_volume * cell_density / 1e12

# %%
# calculate concentration (mmol per g cell dry weight)
df_ac["mmol_per_gDW"] = df_ac["mmol_per_cell"] / cell_mass

# %%
# extract experimental growth rate
growth_experimental = exp_details.loc[
    (exp_details["Growth condition"] == condition) &
    (exp_details["Strain"] == "BW25113"),
    "Growth rate (h-1)"
].mean()
growth_experimental
# Out:
# np.float64(0.58)

# %%
proteomics = df_ac["mmol_per_gDW"]
proteomics.index = df_ac["uniprot"]

# %% [markdown]
# ### Integrate proteomics

# %%
limit_proteins(model, proteomics)
fluxes_ec = cobra.flux_analysis.pfba(model)
model.summary()
# Out:
# 856 proteins constrained
# <h3>Objective</h3><p>1.0 BIOMASS_Ec_iML1515_core_75p37M = 0.0020780823796923624</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e_REV</td>
#       <td>1.082E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e_REV</td>
#       <td>1.082E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e_REV</td>
#       <td>1.473E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e_REV</td>
#       <td>3.338E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e_REV</td>
#       <td>1.945</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e_REV</td>
#       <td>0.0004056</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e_REV</td>
#       <td>1.803E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e_REV</td>
#       <td>1.436E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e_REV</td>
#       <td>0.02243</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ni2_e</td>
#       <td>EX_ni2_e_REV</td>
#       <td>6.712E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e_REV</td>
#       <td>2.574</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e_REV</td>
#       <td>0.002</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e_REV</td>
#       <td>0.0005219</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e_REV</td>
#       <td>7.086E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00934</td>
#       <td>prot_P00934_exchange</td>
#       <td>3.035E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06999</td>
#       <td>prot_P06999_exchange</td>
#       <td>3.469E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08839</td>
#       <td>prot_P08839_exchange</td>
#       <td>2.798E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6A3</td>
#       <td>prot_P0A6A3_exchange</td>
#       <td>2.71E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6C5</td>
#       <td>prot_P0A6C5_exchange</td>
#       <td>2.189E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6E4</td>
#       <td>prot_P0A6E4_exchange</td>
#       <td>2.485E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6E6</td>
#       <td>prot_P0A6E6_exchange</td>
#       <td>9.308E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6P9</td>
#       <td>prot_P0A6P9_exchange</td>
#       <td>2.437E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6T1</td>
#       <td>prot_P0A6T1_exchange</td>
#       <td>1.915E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A6T5</td>
#       <td>prot_P0A6T5_exchange</td>
#       <td>1.103E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A717</td>
#       <td>prot_P0A717_exchange</td>
#       <td>8.151E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A796</td>
#       <td>prot_P0A796_exchange</td>
#       <td>2.568E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A799</td>
#       <td>prot_P0A799_exchange</td>
#       <td>3.69E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A858</td>
#       <td>prot_P0A858_exchange</td>
#       <td>5.917E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A953</td>
#       <td>prot_P0A953_exchange</td>
#       <td>1.111E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A9B2</td>
#       <td>prot_P0A9B2_exchange</td>
#       <td>1.388E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A9C5</td>
#       <td>prot_P0A9C5_exchange</td>
#       <td>3.012E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0A9N4</td>
#       <td>prot_P0A9N4_exchange</td>
#       <td>4.063E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AA04</td>
#       <td>prot_P0AA04_exchange</td>
#       <td>2.798E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AAJ3</td>
#       <td>prot_P0AAJ3_exchange</td>
#       <td>3.809E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AB71</td>
#       <td>prot_P0AB71_exchange</td>
#       <td>2.636E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AB77</td>
#       <td>prot_P0AB77_exchange</td>
#       <td>2.162E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AB98</td>
#       <td>prot_P0AB98_exchange</td>
#       <td>9.308E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0ABA0</td>
#       <td>prot_P0ABA0_exchange</td>
#       <td>9.308E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0ABA4</td>
#       <td>prot_P0ABA4_exchange</td>
#       <td>9.308E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0ABA6</td>
#       <td>prot_P0ABA6_exchange</td>
#       <td>9.308E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0ABB0</td>
#       <td>prot_P0ABB0_exchange</td>
#       <td>9.308E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0ABB4</td>
#       <td>prot_P0ABB4_exchange</td>
#       <td>9.308E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0ABJ9</td>
#       <td>prot_P0ABJ9_exchange</td>
#       <td>1.539E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0ABK2</td>
#       <td>prot_P0ABK2_exchange</td>
#       <td>1.539E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AC69</td>
#       <td>prot_P0AC69_exchange</td>
#       <td>4.253E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AD61</td>
#       <td>prot_P0AD61_exchange</td>
#       <td>1.149E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AE08</td>
#       <td>prot_P0AE08_exchange</td>
#       <td>5.14E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AEK2</td>
#       <td>prot_P0AEK2_exchange</td>
#       <td>1.77E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AEK7</td>
#       <td>prot_P0AEK7_exchange</td>
#       <td>3.809E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AEN1</td>
#       <td>prot_P0AEN1_exchange</td>
#       <td>1.27E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P0AGB0</td>
#       <td>prot_P0AGB0_exchange</td>
#       <td>3.94E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P11446</td>
#       <td>prot_P11446_exchange</td>
#       <td>1.156E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P15254</td>
#       <td>prot_P15254_exchange</td>
#       <td>5.165E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P17854</td>
#       <td>prot_P17854_exchange</td>
#       <td>4.253E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P19642</td>
#       <td>prot_P19642_ex

# %% [markdown]
# We observe that the growth rate is now very low. This is because we have just included more than 800 new constraints and their experimental errors add up (error of proteomics, kcat, cell volume, growth rate...)

# %% [markdown]
# ### We need to relax some constraints
# To do that, we relax proteins that influence the growth rate the most (have the highest shadow prices) one by one until the target growth rate is eached.

# %%
biomass_reaction = "BIOMASS_Ec_iML1515_core_75p37M"
new_growth_rate, prots_removed = flexibilize_proteomics(model, biomass_reaction, growth_experimental*0.9, proteomics)
# Out:
# 856 proteins constrained
# ('P0A7E3', 0.0021852961158732405)
# ('P15254', 0.004457037619397332)
# ('P60782', 0.004457037619397327)
# ('P31119', 0.005651912732149105)
# ('P0A6X1', 0.007640210434326104)
# ('P76503', 0.00956438923148914)
# ('P0A6C5', 0.012239313391691826)
# ('P0AD65', 0.014746204088427882)
# ('P27300', 0.02176225500135444)
# ('P0AD68', 0.02278736676446963)
# ('P17854', 0.026970919238607404)
# ('Q47146', 0.028359133859360345)
# ('P0AC16', 0.03427691464670186)
# ('P0ABG1', 0.03439475061970667)
# ('P0A6W3', 0.04014710652204264)
# ('P14900', 0.043275603715657945)
# ('P09029', 0.059357485282239206)
# ('P0A6I9', 0.07494231347027583)
# ('P00547', 0.07507415913005776)
# ('P11446', 0.0984563984651124)
# ('P17952', 0.10401071090871421)
# ('P0A953', 0.1047667664929614)
# ('P0A725', 0.1067104203682164)
# ('P77718', 0.12696195150992715)
# ('P22939', 0.12729775425948878)
# ('P0AC75', 0.13671965171107478)
# ('P09053', 0.15044444336818594)
# ('P15639', 0.1552581791325787)
# ('P08178', 0.1606482298753211)
# ('P0A6E4', 0.18276697146971316)
# ('P22188', 0.19402771142694508)
# ('P25516', 0.20742898549093214)
# ('P00934', 0.20850215914832307)
# ('P56580', 0.2085021591483178)
# ('P76014', 0.21182937392532938)
# ('P37349', 0.22034089732985293)
# ('P76015', 0.2294932372879551)
# ('P0AGG0', 0.2316150666201498)
# ('P00861', 0.231651842514515)
# ('P0A9P4', 0.23182325637623508)
# ('P0AED7', 0.24278885804056188)
# ('P06983', 0.24506048574197808)
# ('P22634', 0.25450311180180973)
# ('P05020', 0.2676043155482564)
# ('P30011', 0.26773748573758843)
# ('P76085', 0.2677374857375846)
# ('P76078', 0.2677374857375846)
# ('P76081', 0.2677374857375841)
# ('P0AC44', 0.2699897657301062)
# ('P02918', 0.27099411106892357)
# ('P69054', 0.27332258688329997)
# ('P0AEK2', 0.2745026784216472)
# ('P0AC41', 0.27632182810610634)
# ('P0A6V8', 0.27659606088158534)
# ('P07014', 0.27731984471842736)
# ('P68699', 0.2784554266158705)
# ('P0AB98', 0.27943123901562383)
# ('P0ABA6', 0.2859888182174067)
# ('P0ABA4', 0.2883556292489692)
# ('P0ABA0', 0.2927507618132411)
# ('P0A6E6', 0.2931436704767579)
# ('P04079', 0.2955256598773601)
# ('P0ABB0', 0.3041064844117434)
# ('P33607', 0.30518528518949467)
# ('P0AFE8', 0.3054712672292339)
# ('P0ABB4', 0.3065957395716227)
# ('P0AFF0', 0.31215591945178933)
# ('P0AC69', 0.31274378302838857)
# ('P05041', 0.3183902312438992)
# ('P0AFD4', 0.3199880376893237)
# ('P62620', 0.3225237618329398)
# ('P0AC13', 0.3238160718379858)
# ('P0A9C5', 0.3254195299934204)
# ('P0AFE4', 0.32637197844315524)
# ('P0AFC7', 0.3266956502203742)
# ('P0AFD6', 0.33128543570383084)
# ('P08373', 0.3348524389389179)
# ('P31979', 0.34427655484796893)
# ('P21645', 0.3509281057339912)
# ('P0AFC3', 0.35656874017166196)
# ('P0AFD1', 0.368493786857749)
# ('P33602', 0.37893103776734943)
# ('P33599', 0.38865300349597043)
# ('P06988', 0.3949651128644314)
# ('P00561', 0.4000429202866061)
# ('P0A7B5', 0.40413284765744323)
# ('P17443', 0.4576144666819954)
# ('P0A7J0', 0.4628365644400274)
# ('P22255', 0.47942763405990857)
# ('P00893', 0.4981638420941942)
# ('P62615', 0.5123970817637947)
# ('P0A7D4', 0.525877420175977)

# %% [markdown]
# We see that only a small fraction of proteins needed to be relaxed

# %%
percentage_removed = round(len(prots_removed)/proteomics.shape[0]*100, 1)
print(f"Proteins in dataset: {proteomics.shape[0]}\nProteins removed: {len(prots_removed)} ({percentage_removed}%)")
# Out:
# Proteins in dataset: 2057
# Proteins removed: 92 (4.5%)

# %%
fluxes_ec_unblocked = cobra.flux_analysis.pfba(model)
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ec_iML1515_core_75p37M = 0.525877420175977</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e_REV</td>
#       <td>0.002737</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e_REV</td>
#       <td>0.002737</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e_REV</td>
#       <td>1.315E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e_REV</td>
#       <td>0.0003728</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e_REV</td>
#       <td>0.008446</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e_REV</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>k_e</td>
#       <td>EX_k_e_REV</td>
#       <td>0.1026</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mg2_e</td>
#       <td>EX_mg2_e_REV</td>
#       <td>0.004562</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mn2_e</td>
#       <td>EX_mn2_e_REV</td>
#       <td>0.0003634</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>mobd_e</td>
#       <td>EX_mobd_e_REV</td>
#       <td>3.681E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e_REV</td>
#       <td>5.679</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ni2_e</td>
#       <td>EX_ni2_e_REV</td>
#       <td>0.0001699</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e_REV</td>
#       <td>30.79</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e_REV</td>
#       <td>0.5073</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>so4_e</td>
#       <td>EX_so4_e_REV</td>
#       <td>0.1324</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>zn2_e</td>
#       <td>EX_zn2_e_REV</td>
#       <td>0.0001793</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_O32583</td>
#       <td>prot_O32583_exchange</td>
#       <td>2.715E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00350</td>
#       <td>prot_P00350_exchange</td>
#       <td>2.271E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00547</td>
#       <td>prot_P00547_exchange</td>
#       <td>2E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00561</td>
#       <td>prot_P00561_exchange</td>
#       <td>1.72E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00562</td>
#       <td>prot_P00562_exchange</td>
#       <td>2.94E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00861</td>
#       <td>prot_P00861_exchange</td>
#       <td>3.203E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00864</td>
#       <td>prot_P00864_exchange</td>
#       <td>4.206E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00893</td>
#       <td>prot_P00893_exchange</td>
#       <td>1.582E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00894</td>
#       <td>prot_P00894_exchange</td>
#       <td>1.582E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00903</td>
#       <td>prot_P00903_exchange</td>
#       <td>1.459E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00904</td>
#       <td>prot_P00904_exchange</td>
#       <td>1.947E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00909</td>
#       <td>prot_P00909_exchange</td>
#       <td>1.059E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00934</td>
#       <td>prot_P00934_exchange</td>
#       <td>9.149E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00935</td>
#       <td>prot_P00935_exchange</td>
#       <td>1.858E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P00963</td>
#       <td>prot_P00963_exchange</td>
#       <td>7.944E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P02918</td>
#       <td>prot_P02918_exchange</td>
#       <td>7.807E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04036</td>
#       <td>prot_P04036_exchange</td>
#       <td>2.852E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04079</td>
#       <td>prot_P04079_exchange</td>
#       <td>1.487E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04693</td>
#       <td>prot_P04693_exchange</td>
#       <td>1.16E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04805</td>
#       <td>prot_P04805_exchange</td>
#       <td>2.369E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P04951</td>
#       <td>prot_P04951_exchange</td>
#       <td>2.596E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05020</td>
#       <td>prot_P05020_exchange</td>
#       <td>1.948E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05041</td>
#       <td>prot_P05041_exchange</td>
#       <td>1.459E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05194</td>
#       <td>prot_P05194_exchange</td>
#       <td>1.796E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05791</td>
#       <td>prot_P05791_exchange</td>
#       <td>1.296E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P05793</td>
#       <td>prot_P05793_exchange</td>
#       <td>6.549E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06959</td>
#       <td>prot_P06959_exchange</td>
#       <td>1.667E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06983</td>
#       <td>prot_P06983_exchange</td>
#       <td>1.042E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06988</td>
#       <td>prot_P06988_exchange</td>
#       <td>9.544E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06989</td>
#       <td>prot_P06989_exchange</td>
#       <td>2.796E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P06999</td>
#       <td>prot_P06999_exchange</td>
#       <td>3.469E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07004</td>
#       <td>prot_P07004_exchange</td>
#       <td>3.635E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07014</td>
#       <td>prot_P07014_exchange</td>
#       <td>1.515E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P07623</td>
#       <td>prot_P07623_exchange</td>
#       <td>6.123E-07</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08142</td>
#       <td>prot_P08142_exchange</td>
#       <td>2.614E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08178</td>
#       <td>prot_P08178_exchange</td>
#       <td>1.635E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08200</td>
#       <td>prot_P08200_exchange</td>
#       <td>2.063E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08244</td>
#       <td>prot_P08244_exchange</td>
#       <td>1.151E-06</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>prot_P08373</td>
#       <td>prot_P08373_exchange</td>
#       <td>2.023E-07</td>

# %% [markdown]
# ### Next steps
# As a next step, we could for example
# * visualize the fluxes in Escher or other software
#     * compare it to unconstrained model - are the flux distributions different? Are different products secreted?
#     * compare the different conditions (e.g. ask how does the metabolism rewire in rich vs poor medium, high temperature and other stressors...)
# * perform flux variability analysis or sampling to characterize the solution space

# %%
flux_series = fluxes_unconstrained.fluxes.copy()
flux_series_ec = fluxes_ec_unblocked.fluxes.copy()

def normalize_rxn_id(rxn_id):
    rxn = re.sub(r'_REV$', '', rxn_id)
    rxn = re.sub(r'ppNo\d+$', '', rxn)
    rxn = re.sub(r'No\d+$', '', rxn)
    rxn = re.sub(r'pp$', '', rxn)

    return rxn

# %%
def process_ec_fluxes(flux_series):

    df = flux_series.reset_index()
    df.columns = ['rxn_id', 'flux']
    
    df['is_rev'] = df['rxn_id'].str.endswith('_REV')
    df['base_id'] = df['rxn_id'].apply(normalize_rxn_id)
    df['signed_flux'] = df['flux'] * df['is_rev'].map({True: -1, False: 1})
    net_flux_df = (
        df.groupby('base_id', as_index=False)['signed_flux']
          .sum()
          .rename(columns={'signed_flux': 'net_flux'})
    )
    net_flux_df = net_flux_df.set_index('base_id')

    return net_flux_df

# %%
processed_fluxes = process_ec_fluxes(flux_series)
processed_fluxes_ec = process_ec_fluxes(flux_series_ec)

# %%
# biomass reaction has a different name in the e coli core map
processed_fluxes.loc["BIOMASS_Ecoli_core_w_GAM"] = processed_fluxes.loc[biomass_reaction]
processed_fluxes_ec.loc["BIOMASS_Ecoli_core_w_GAM"] = processed_fluxes_ec.loc[biomass_reaction]

# %%
builder = escher.Builder('e_coli_core.Core metabolism',
                       reaction_data=processed_fluxes_ec.net_flux)
builder.save_html(f"../results/ecFBA.html")
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/e_coli_core.Core%20metabolism.json

# %%
builder2 = escher.Builder('e_coli_core.Core metabolism',
                       reaction_data=processed_fluxes.net_flux)
builder2.save_html(f"../results/FBA.html")
# Out:
# Downloading Map from https://escher.github.io/1-0-0/6/maps/Escherichia%20coli/e_coli_core.Core%20metabolism.json

# %% [markdown]
# ### we see that the mapping of the fluxes on the e_coli_core map is not perfect
# * the models might have slightly different naming - we would have to map it
# * genome scale models have much more possible solutions - maybe the reactions are not in the map
